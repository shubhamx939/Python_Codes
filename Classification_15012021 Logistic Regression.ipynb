# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("titanic_train.csv")
data1.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
survived = pd.read_csv("gender_baseline.csv")
survived.head()
# Out:
#    passenger_id  survived
# 0           295         0
# 1          1150         0
# 2            89         0
# 3          1063         0
# 4          1020         0

# %%
data2 = pd.read_csv("titanic_test.csv")
data2["survived"] = survived["survived"]
data2.head()
# Out:
#    passenger_id  pclass                            name   sex   age  sibsp  \
# 0           295       1     Thayer, Mr. John Borland Jr  male  17.0      0
# 1          1150       3        Risien, Mr. Samuel Beard  male   NaN      0
# 2            89       1          Davidson, Mr. Thornton  male  31.0      1
# 3          1063       3  Nirva, Mr. Iisakki Antino Aijo  male  41.0      0
# 4          1020       3              Minkoff, Mr. Lazar  male  21.0      0
#
#    parch            ticket      fare cabin embarked boat  body  \
# 0      2             17421  110.8833   C70        C    B   NaN
# 1      0            364498   14.5000   NaN        S  NaN   NaN
# 2      0        F.C. 12750   52.0000   B71        S  NaN   NaN
# 3      0  SOTON/O2 3101272    7.1250   NaN        S  NaN   NaN
# 4      0            349211    7.8958   NaN        S  NaN   NaN
#
#              home.dest  survived
# 0        Haverford, PA         0
# 1                  NaN         0
# ...

# %%
# combine both table
data = data1.append(data2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 458
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  1309 non-null   int64
#  1   pclass        1309 non-null   int64
#  2   name          1309 non-null   object
#  3   sex           1309 non-null   object
#  4   age           1046 non-null   float64
#  5   sibsp         1309 non-null   int64
#  6   parch         1309 non-null   int64
#  7   ticket        1309 non-null   object
#  8   fare          1308 non-null   float64
#  9   cabin         295 non-null    object
#  10  embarked      1307 non-null   object
#  11  boat          486 non-null    object
#  12  body          121 non-null    float64
#  13  home.dest     745 non-null    object
#  14  survived      1309 non-null   int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 163.6+ KB

# %%
# descriptive analysis
data.describe().transpose()
# Out:
#                count        mean         std     min       25%       50%  \
# passenger_id  1309.0  654.000000  378.020061  0.0000  327.0000  654.0000
# pclass        1309.0    2.294882    0.837836  1.0000    2.0000    3.0000
# age           1046.0   29.881135   14.413500  0.1667   21.0000   28.0000
# sibsp         1309.0    0.498854    1.041658  0.0000    0.0000    0.0000
# parch         1309.0    0.385027    0.865560  0.0000    0.0000    0.0000
# fare          1308.0   33.295479   51.758668  0.0000    7.8958   14.4542
# body           121.0  160.809917   97.696922  1.0000   72.0000  155.0000
# survived      1309.0    0.366692    0.482086  0.0000    0.0000    0.0000
#
#                   75%        max
# passenger_id  981.000  1308.0000
# pclass          3.000     3.0000
# age            39.000    80.0000
# sibsp           1.000     8.0000
# parch           0.000     9.0000
# fare           31.275   512.3292
# body          256.000   328.0000
# survived        1.000     1.0000

# %%
# how many people survived
data["survived"].sum()
# Out:
# 480

# %%
data["survived"].mean()
# Out:
# 0.36669213139801377

# %%
data.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
data["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data.groupby("sex").sum()["survived"]
# Out:
# sex
# female    377
# male      103
# Name: survived, dtype: int64

# %%
data.groupby("sex").sum()["survived"].plot.bar()
plt.show()

# %%
data.groupby("pclass").sum()["survived"]
# Out:
# pclass
# 1    175
# 2    115
# 3    190
# Name: survived, dtype: int64

# %%
data1 = pd.read_csv("titanic_train.csv")
data1.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
data1 = data1[["pclass","sex","age","sibsp","parch","fare","survived"]]
data1
# Out:
#      pclass     sex   age  sibsp  parch     fare  survived
# 0         3  female   NaN      0      0   7.7333         1
# 1         3    male  38.0      0      0   8.6625         0
# 2         3  female  30.0      1      1  24.1500         0
# 3         2  female  54.0      1      3  23.0000         1
# 4         2    male  40.0      0      0  13.0000         0
# ..      ...     ...   ...    ...    ...      ...       ...
# 845       1    male  55.0      0      0  50.0000         0
# 846       1    male  58.0      0      0  29.7000         0
# 847       2  female  24.0      1      0  26.0000         1
# 848       3  female   3.0      1      1  13.7750         0
# 849       2    male  52.0      0      0  13.0000         0
#
# [850 rows x 7 columns]

# %%
data1["age"] = data1["age"].fillna(data1["age"].median())

# %%
data1
# Out:
#      pclass     sex   age  sibsp  parch     fare  survived
# 0         3  female  28.0      0      0   7.7333         1
# 1         3    male  38.0      0      0   8.6625         0
# 2         3  female  30.0      1      1  24.1500         0
# 3         2  female  54.0      1      3  23.0000         1
# 4         2    male  40.0      0      0  13.0000         0
# ..      ...     ...   ...    ...    ...      ...       ...
# 845       1    male  55.0      0      0  50.0000         0
# 846       1    male  58.0      0      0  29.7000         0
# 847       2  female  24.0      1      0  26.0000         1
# 848       3  female   3.0      1      1  13.7750         0
# 849       2    male  52.0      0      0  13.0000         0
#
# [850 rows x 7 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
d = {"female":0,"male":1}
data1["sex"] = data1["sex"].map(d)

# %%
data1
# Out:
#      pclass  sex   age  sibsp  parch     fare  survived
# 0         3    0  28.0      0      0   7.7333         1
# 1         3    1  38.0      0      0   8.6625         0
# 2         3    0  30.0      1      1  24.1500         0
# 3         2    0  54.0      1      3  23.0000         1
# 4         2    1  40.0      0      0  13.0000         0
# ..      ...  ...   ...    ...    ...      ...       ...
# 845       1    1  55.0      0      0  50.0000         0
# 846       1    1  58.0      0      0  29.7000         0
# 847       2    0  24.0      1      0  26.0000         1
# 848       3    0   3.0      1      1  13.7750         0
# 849       2    1  52.0      0      0  13.0000         0
#
# [850 rows x 7 columns]

# %%
X = data1[["pclass","sex","age","sibsp","parch","fare"]]
Y = data1["survived"]

# %%
model = LogisticRegression()

# %%
# we get error only when there is Nan value in data
model.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-af69984aa28e> in <module>
#       1 # we get error only when there is Nan value in data
# ----> 2 model.fit(X,Y)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1340             _dtype = [np.float64, np.float32]
#    1341
# -> 1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
#    1344                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
# ...

# %%
X["age"] = X["age"].fillna(X["age"].median())

# %%
X.info()

# %%
X["fare"] = X["fare"].fillna(0)

# %%
X.info()

# %%
model.fit(X,Y)

# %%
data2 = pd.read_csv("titanic_test.csv")

# %%
X_test = data2[["pclass","sex","age","sibsp","parch","fare"]]

# %%
X_test.info()

# %%
X_test["age"] = X_test["age"].fillna(28)

# %%
X_test.info()

# %%
X_test["sex"] = X_test["sex"].map(d)

# %%
Y_pred = model.predict(X_test)

# %%
Y_test = survived["survived"].values

# %%
(Y_pred == Y_test).mean()

# %%
from sklearn.metrics import confusion_matrix,precision_recall_fscore_support

# %%
confusion_matrix(Y_pred , Y_test)

# %%
precision_recall_fscore_support(Y_pred , Y_test, average="weighted")
