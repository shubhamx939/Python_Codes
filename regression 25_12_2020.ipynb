# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

x = np.arange(0,10,0.1)

y1 = 10*x+1

y2 = 5*x+1

y3 = 5*x+4

plt.plot(x,y1,"b", label="m=10 c=1")
plt.plot(x,y2,"g", label="m=5 c=1")
plt.plot(x,y3,"r", label="m=5 c=4")

plt.legend()
plt.show()
