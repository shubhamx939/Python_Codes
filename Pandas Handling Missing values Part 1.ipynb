# %% [markdown]
# # Handling Missing values of a file in Python (Part 1):

# %%
import pandas as pd

# %% [markdown]
# # Syntax======>>>>

# %% [markdown]
# ###### pandas.read_csv(filepath_or_buffer, sep=', ', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, skip_footer=0, doublequote=True, delim_whitespace=False, as_recarray=None, compact_ints=None, use_unsigned=None, low_memory=True, buffer_lines=None, memory_map=False, float_precision=None)

# %%
df = pd.read_csv("Fortune_10.csv")
df
# Out:
#    ID Confirmation             Name             Industry  Inception  \
# 0   1          Yes          Lamtone          IT Services       2009
# 1   2          Yes        Stripfind   Financial Services       2010
# 2   3           No  Canecorporation               Health       2012
# 3   4          Yes         Mattouch          IT Services       2013
# 4   5          Yes        Techdrill               Health       2009
# 5   6           No         Techline               Health       2006
# 6   7          Yes          Cityace               Health       2010
# 7   8           No   Kayelectronics               Health       2009
# 8   9          Yes          Ganzlax          IT Services       2011
# 9  10          Yes      Trantraxlax  Government Services       2011
#
#         Revenue           Expenses    Profit Growth Missing Values
# 0  $11,757,018   6,482,465 Dollars   5274553    30%            Yes
# 1  $12,329,371     916,455 Dollars  11412916    20%  not available
# ...

# %% [markdown]
# # Checking Null "NaN" values:

# %%
df = pd.read_csv("Fortune_10.csv", na_values = "not available")
df
# Out:
#    ID Confirmation             Name             Industry  Inception  \
# 0   1          Yes          Lamtone          IT Services       2009
# 1   2          Yes        Stripfind   Financial Services       2010
# 2   3           No  Canecorporation               Health       2012
# 3   4          Yes         Mattouch          IT Services       2013
# 4   5          Yes        Techdrill               Health       2009
# 5   6           No         Techline               Health       2006
# 6   7          Yes          Cityace               Health       2010
# 7   8           No   Kayelectronics               Health       2009
# 8   9          Yes          Ganzlax          IT Services       2011
# 9  10          Yes      Trantraxlax  Government Services       2011
#
#         Revenue           Expenses    Profit Growth Missing Values
# 0  $11,757,018   6,482,465 Dollars   5274553    30%            Yes
# 1  $12,329,371     916,455 Dollars  11412916    20%            NaN
# ...

# %%
df = pd.read_csv("Fortune_10.csv", na_values = ["not available","no values"])
df
# Out:
#    ID Confirmation             Name             Industry  Inception  \
# 0   1          Yes          Lamtone          IT Services       2009
# 1   2          Yes        Stripfind   Financial Services       2010
# 2   3           No  Canecorporation               Health       2012
# 3   4          Yes         Mattouch          IT Services       2013
# 4   5          Yes        Techdrill               Health       2009
# 5   6           No         Techline               Health       2006
# 6   7          Yes          Cityace               Health       2010
# 7   8           No   Kayelectronics               Health       2009
# 8   9          Yes          Ganzlax          IT Services       2011
# 9  10          Yes      Trantraxlax  Government Services       2011
#
#         Revenue           Expenses    Profit Growth Missing Values
# 0  $11,757,018   6,482,465 Dollars   5274553    30%            Yes
# 1  $12,329,371     916,455 Dollars  11412916    20%            NaN
# ...

# %%
df = pd.read_csv("Fortune_10.csv")
df
# Out:
#    ID Confirmation             Name             Industry  Inception  \
# 0   1          Yes          Lamtone          IT Services       2009
# 1   2          Yes        Stripfind   Financial Services       2010
# 2   3           No  Canecorporation               Health       2012
# 3   4          Yes         Mattouch          IT Services       2013
# 4   5          Yes        Techdrill               Health       2009
# 5   6           No         Techline               Health       2006
# 6   7          Yes          Cityace               Health       2010
# 7   8           No   Kayelectronics               Health       2009
# 8   9          Yes          Ganzlax          IT Services       2011
# 9  10          Yes      Trantraxlax  Government Services       2011
#
#         Revenue           Expenses    Profit Growth Missing Values
# 0  $11,757,018   6,482,465 Dollars   5274553    30%            Yes
# 1  $12,329,371     916,455 Dollars  11412916    20%  not available
# ...

# %%
df = pd.read_csv("Fortune_10.csv", na_values = {"Missing Values":"not available", "Expenses":"no value"})
df
# Out:
#    ID Confirmation             Name             Industry  Inception  \
# 0   1          Yes          Lamtone          IT Services       2009
# 1   2          Yes        Stripfind   Financial Services       2010
# 2   3           No  Canecorporation               Health       2012
# 3   4          Yes         Mattouch          IT Services       2013
# 4   5          Yes        Techdrill               Health       2009
# 5   6           No         Techline               Health       2006
# 6   7          Yes          Cityace               Health       2010
# 7   8           No   Kayelectronics               Health       2009
# 8   9          Yes          Ganzlax          IT Services       2011
# 9  10          Yes      Trantraxlax  Government Services       2011
#
#         Revenue           Expenses    Profit Growth Missing Values
# 0  $11,757,018   6,482,465 Dollars   5274553    30%            Yes
# 1  $12,329,371     916,455 Dollars  11412916    20%            NaN
# ...
